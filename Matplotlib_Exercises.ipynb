# %% [markdown]
# <a href="https://colab.research.google.com/github/majedalnowab/my-first-repo/blob/main/Matplotlib_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization with Python using Matplotlib -- Exercises - Solutions
#
# Hi Guys,<br>
# Welcome to the matplotlib exercises lecture. <br>
#
# Please follow the instructions while solving the exercises. These are relatively easy tasks, if you are new to matplotlib, the tasks may be tricky. You can always reference to the solutions if you find things complicated.
#
# &#9989; Please note, the commands for plotting figures should go all together in the same cell. Splitting them in multiple cells may not show the results. <br>
# Let's have a quick overview on the tasks. <br>
#
# In the first cell, we are simply creating data x and y to use in the provided tasks.

# %%
# We need data to work with, lets create data first!
import numpy as np
x = np.arange(0,10)
y = x*2
z = x**2

# %% [markdown]
# &#9758; If you are a jupyter users:
# * Let's import <code>**matplotlib.pyplot as plt**</code> and set <code>**%matplotlib inline**</code>.
#
# If you are not using jupyter notebook, you will use <code>**plt.show()**</code>

# %%
import matplotlib.pyplot as plt
# plt.show() for non-notebook users

# %% [markdown]
# **1. Instructions:**
# * ** Use <code>plt.figure()</code> and create a figure object, say fig.**
# * ** Add an axis to the figure canvas (`fig`), `[left, bottom, width, height] is [0,0,1,1]`. <i>Hint: <code>add_axes()</code><i>**
# * ** Plot the data x,y on the axes**
# * ** Set the labels x and y**
# * ** Set the title**
# * ** Create legends as shown in the plot**
#
# Match the output below:

# %%
#Code here
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, 'g', label='y = x*2')

ax.set_xlabel('x_label')
ax.set_ylabel('y_label')
ax.set_title('Plot_title')

ax.legend(loc=4)

# %% [markdown]
# **2. Instructions**<br>
# * ** Create a figure object**
# * ** Put two axes on the figure at [0,0,1,1] and [0.1,0.6,0.2,0.2]**
# * ** Plot data (x,z) on main axes**
# * ** Plot data (x,z) on the small axes and set its x limit b/w 1, 2, y limit 0, 5**
# * ** Replicate the figure to axes, titles, legends etc**

# %%
#Code here
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(x, z, 'r', label='y_main = x_main**2')

ax2 = fig.add_axes([0.1, 0.6, 0.2, 0.2])
ax2.plot(x, z, 'b')

ax2.set_xlim(1, 2)
ax2.set_ylim(0, 5)

ax1.set_xlabel('x_main')
ax1.set_ylabel('y_main')
ax1.set_title('Title_main')
ax1.legend(loc=4)

ax2.set_xlabel('x_inset')
ax2.set_ylabel('y_inset')
ax2.set_title('inset')
plt.plot()
# Out:
# []

# %% [markdown]
# **3. Replicate the output using <code>subplots()</code> and for loop** -- Note, the data is x and y.

# %%
#Code here
plt.subplot(1, 3, 1)
plt.plot(x, y, '')

plt.subplot(1, 3, 2)
plt.plot(x, y, '')

plt.subplot(1, 3, 3)
plt.plot(x, y, '')

plt.tight_layout()
plt.show()

# %% [markdown]
# **4. Replicate the output using <code>subplots()</code>**

# %%
#Code here
fig, axes = plt.subplots(3,1)

for ax in axes:
    ax.set_xlim(0, 1)
    ax.set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
    ax.set_ylim(0, 1)
    ax.set_yticks([0, 0.5, 1])

plt.show()

# %% [markdown]
# **5. plot `(x,y)`, `(x,z)` and `(x,y)` on the above empty canvas to replicate the plot given below.**

# %%
#Code here
fig, axes = plt.subplots(3, 1, figsize=(20, 1))
plt.subplot(1,3,1)
plt.plot(x,y, 'b--', linewidth=2.00)

fig, axes = plt.subplots(3, 1, figsize=(20, 1))
plt.subplot(1,3,2)
plt.plot(x,z, 'r', linewidth=2.00)

fig, axes = plt.subplots(3, 1, figsize=(20, 1))
plt.subplot(1,3,3)
plt.plot(x,y, 'g',linewidth=2.00)
plt.show()
# Out:
# <ipython-input-29-3faee17698c4>:3: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)
# <ipython-input-29-3faee17698c4>:7: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,2)
# <ipython-input-29-3faee17698c4>:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,3)

# %% [markdown]
# **6. Resize the above plots to `figsize = (3,4)`**

# %%
#Code here
fig, axes = plt.subplots(3,1, figsize = (3,4))
axes[0].plot(x, y, 'b--')
axes[1].plot(x, z, 'r')
axes[2].plot(x, y, 'g')
plt.tight_layout()
plt.plot()
# Out:
# []

# %% [markdown]
# **7. Replicate the plot given below:**<br>
# *hint: scatter plot*

# %%
#Code here
plt.scatter(x, z, marker='s')

# %% [markdown]
# # Excellent, Good Job!
